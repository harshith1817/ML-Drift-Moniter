# %%
from src.preprocessing import dynamic_preprocessor
from src.model import train_model


def main():
    x,y=dynamic_preprocessor("data/teleco_customer_churn_train.csv","Churn")
    model=train_model(x,y)


if __name__=="__main__":
    main()
# Out:
# Preprocesing is done!
# Baseline Accuracy: 0.783226723525231
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 11
#       7     model=train_model(x,y)
#      10 if __name__=="__main__":
# ---> 11     main()
#
# Cell In[17], line 7, in main()
#       5 def main():
#       6     x,y=dynamic_preprocessor("data/teleco_customer_churn_train.csv","Churn")
# ----> 7     model=train_model(x,y)
#
# File C:\Projects\ML Drift Monitor\src\model.py:26, in train_model(inputs, target)
#      24 accuracy=model.score(inputs_test, target_test)
#      25 print("Baseline Accuracy:", accuracy)
# ---> 26 joblib.dump(model, "../models/model.pkl")
#      27 return model, inputs, accuracy
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\numpy_pickle.py:552, in dump(value, filename, compress, protocol, cache_size)
#     550         NumpyPickler(f, protocol=protocol).dump(value)
#     551 elif is_filename:
# --> 552     with open(filename, 'wb') as f:
#     553         NumpyPickler(f, protocol=protocol).dump(value)
#     554 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/model.pkl'
